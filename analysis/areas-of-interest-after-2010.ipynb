# %% [markdown]
# # Selecting areas of interest for our reporting - incidents after 2010, pipelines installed after 2010

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# /Users/ilenapeng/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df_raw = pd.read_csv('../data/processed/pipeline_incidents_2010_present_all_CLEAN.csv')
df_raw.head()
# Out:
#   datafile_as_of  ff significant serious  report_number  supplemental_number  \
# 0        2/28/22  NO         YES      NO       20100001                15047
# 1        2/28/22  NO          NO      NO       20100002                15553
# 2        2/28/22  NO          NO      NO       20100003                15023
# 3        2/28/22  NO         YES     YES       20100004                15003
# 4        2/28/22  NO         YES     YES       20100005                15639
#
#   report_received_date         report_type  operator_id  \
# 0              3/11/10  SUPPLEMENTAL FINAL        15007
# 1              3/12/10  SUPPLEMENTAL FINAL        13730
# 2              3/15/10  SUPPLEMENTAL FINAL        31840
# 3              3/16/10      ORIGINAL FINAL        13710
# 4              3/22/10  SUPPLEMENTAL FINAL         6141
#
#                                  name  \
# 0           PACIFIC GAS & ELECTRIC CO
# 1  NORTHERN INDIANA PUBLIC SERVICE CO
# 2           UNISOURCE ENERGY SERVICES
# 3            NORTHERN ILLINOIS GAS CO
# 4              NEW MEXICO GAS COMPANY
#
#                              operator_street_address operator_city_name  \
# 0  PG&E - GAS OPERATIONS, REGULATORY COMPLIANCE 6...          SAN RAMON
# 1                                 801 E 86TH AVENUE        MERRILLVILLE
# 2                             2901 W. SHAMRELL BLVD.          FLAGSTAFF
# 3                        P.O. BOX 190, RT 59 & I-88              AURORA
# 4                      7120 WYOMING BLVD. NE STE, 20       ALBUQUERQUE
#
#   operator_state_abbreviation operator_postal_code local_datetime time_zone  \
# 0                          CA                94583  2/13/10 23:35       NaN
# 1                          IN                46410  2/16/10 10:38       NaN
# 2                          AZ                86001  2/22/10 20:57       NaN
# 3                          IL                60507  2/18/10 19:05       NaN
# 4                          NM                87109   2/21/10 1:38       NaN
#
#   daylight_savings_ind  iyear  location_street_address location_city_name  \
# 0                  NaN   2010     1617 EAST 9TH STREET           STOCKTON
# 1                  NaN   2010  3835 SANDPIPER COVE RUN         SOUTH BEND
# 2                  NaN   2010  8725 COUNTRY CLUB DRIVE            PINETOP
# 3                  NaN   2010     359 HAWTHORNE CIRCLE     MOUNT PROSPECT
# 4                  NaN   2010      303 COUNTY RD. 6100           KIRTLAND
#
#   location_county_name location_state_abbreviation location_postal_code  \
# 0          SAN JOAQUIN                          CA                95201
# 1           ST. JOSEPH                          IN                46628
# 2               NAVAJO                          AZ                85935
# 3                 COOK                          IL                60056
# 4             SAN JUAN                          NM                87417
#
#    location_latitude  location_longitude  total_cost  total_cost_current  \
# 0           37.93188          -121.26133      102500       124764.082311
# 1           41.72931           -86.27531       57500        68334.121206
# 2           34.10934          -109.86010        2648         3173.508982
# 3           42.03668           -87.94307       22005        26781.407382
# 4           36.74350          -108.33380        4843         5871.773935
#
#   injury_ind  injure  num_pub_evacuated  fatal                       cause  \
# 0         NO       0                0.0      0  OTHER OUTSIDE FORCE DAMAGE
# 1         NO       0               20.0      0           EXCAVATION DAMAGE
# 2         NO       0                NaN      0        NATURAL FORCE DAMAGE
# 3        YES       1                NaN      0           CORROSION FAILURE
# 4        YES       1                0.0      0  OTHER OUTSIDE FORCE DAMAGE
#
#                                        cause_details  \
# 0                         OTHER OUTSIDE FORCE DAMAGE
# 1                   EXCAVATION DAMAGE BY THIRD PARTY
# 2                         OTHER NATURAL FORCE DAMAGE
# 3                                 EXTERNAL CORROSION
# 4  DAMAGE BY CAR, TRUCK, OR OTHER MOTORIZED VEHIC...
#
#                                            narrative  unintentional_release  \
# 0  A FIRE AT AN UNOCCUPIED HOME OCCURRED AT APPRO...                   10.0
# 1  CONTRACTOR BORING ELECTRIC LINE PARALLEL TO 3"...                  310.0
# 2  ON 2/22/10 PINETOP FIRE DEPARTMENT RESPONDED T...                   14.0
# 3  CREW WAS DIGGING A HOLE TO FIX A SERVICE LINE ...                    1.0
# 4  A SAN JUAN COUNTY DEPUTY SHERIFF WAS IN PURSUI...                 5625.0
#
#   installation_year
# 0               NaN
# 1        1990-01-01
# 2        1999-01-01
# 3        1976-01-01
# 4               NaN

# %%
# Convert installation_year column to datetime
df_raw['installation_year'] = pd.to_datetime(df_raw['installation_year'], format='%Y-%m-%d')

# %%
# Filter install_year to post 2010
df = df_raw[df_raw.installation_year >= '2010-01-01']

# %% [markdown]
# ## Cities with most pipeline accidents

# %%
df.location_city_name.value_counts().head(20)
# Out:
# DALLAS                       4
# Not Within a Municipality    3
# HOUSTON                      2
# NEW YORK                     2
# ATLANTA                      2
# CHICAGO                      2
# SAN FRANCISCO                2
# DURHAM                       2
# FORT WORTH                   2
# AUSTIN                       1
# BELLEVUE                     1
# WAPPINGERS FALLS             1
# ABERDEEN                     1
# LOS ANGELES                  1
# MARIETTA                     1
# EXCELSIOR                    1
# MIAMI BEACH                  1
# PEPPER PIKE                  1
# NORTH BERGEN                 1
# BROOKLYN                     1
# Name: location_city_name, dtype: int64

# %% [markdown]
# ## Cities with highest total costs for pipeline accidents (adjusted for inflation)
# total_cost variable would give us the estimated total cost

# %%
df_highest_cost = df.groupby(['location_city_name', 'location_state_abbreviation']).total_cost_current.agg(['sum', 'count']).reset_index()
df_highest_cost.sort_values('sum', ascending=False).head(20)
# Out:
#     location_city_name location_state_abbreviation           sum  count
# 5              ATLANTA                          GA  1.033171e+07      2
# 101        PEPPER PIKE                          OH  9.307204e+06      1
# 79          MELVINDALE                          MI  6.073367e+06      1
# 23              CANTON                          IL  4.841442e+06      1
# 87            NEW YORK                          NY  3.651720e+06      2
# 69            LAWRENCE                          MA  2.749868e+06      1
# 13              BERWYN                          IL  2.522560e+06      1
# 41       ELLICOTT CITY                          MD  1.915530e+06      1
# 139           WOODBURY                          MN  1.587926e+06      1
# 110      SAN FRANCISCO                          CA  1.182680e+06      2
# 129          VICKSBURG                          MS  1.085575e+06      1
# 34              DALLAS                          TX  1.014738e+06      4
# 104            RALEIGH                          NC  8.354020e+05      1
# 119        SOUTH POINT                          OH  8.204682e+05      1
# 105           RATHDRUM                          ID  7.781990e+05      1
# 137            WINDSOR                          CO  7.247200e+05      1
# 4                 ALTA                          UT  6.865926e+05      1
# 3                ALLEN                          TX  6.501000e+05      1
# 117             SIDNEY                          OH  5.981692e+05      1
# 39             DUNMORE                          PA  5.976067e+05      1

# %% [markdown]
# ## Cities with highest fatalities and injuries

# %%
df_injure_fatal = df.groupby(['location_city_name', 'location_state_abbreviation']).agg({'fatal' : ['sum'], 'injure' : ['sum', 'count']})
df_injure_fatal.head(2)
# Out:
#                                                fatal injure
#                                                  sum    sum count
# location_city_name location_state_abbreviation
# ABERDEEN           ID                              0      0     1
# ADDIS              LA                              0      1     1

# %%
# remove multi index
df_injure_fatal.columns = df_injure_fatal.columns.droplevel()
df_injure_fatal = df_injure_fatal.reset_index()

# rename columns
df_injure_fatal.columns = ['location_city_name',
                           'location_state_abbreviation',
                           'fatal_sum',
                           'injure_sum',
                           'accident_count']


df_injure_fatal.head()
# Out:
#   location_city_name location_state_abbreviation  fatal_sum  injure_sum  \
# 0           ABERDEEN                          ID          0           0
# 1              ADDIS                          LA          0           1
# 2              AKRON                          OH          0           0
# 3              ALLEN                          TX          0           0
# 4               ALTA                          UT          0           0
#
#    accident_count
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
# Cities with most injuries
df_injure_fatal.sort_values('injure_sum', ascending=False).head(20)
# Out:
#             location_city_name location_state_abbreviation  fatal_sum  \
# 87                    NEW YORK                          NY          8
# 36                     DETROIT                          MI          0
# 23                      CANTON                          IL          1
# 74                  LOST HILLS                          CA          0
# 19                    BROOKLYN                          NY          0
# 123                 SWIFTWATER                          PA          1
# 34                      DALLAS                          TX          0
# 9                      BAYONNE                          NJ          0
# 70               LAWRENCE TWP.                          NJ          0
# 79                  MELVINDALE                          MI          0
# 25                     CHICAGO                          IL          0
# 120                  SPICEWOOD                          TX          0
# 104                    RALEIGH                          NC          0
# 112                   SANTA FE                          NM          0
# 110              SAN FRANCISCO                          CA          0
# 57                     HOLLAND                          IN          0
# 93   Not Within a Municipality                          IA          0
# 85                NEW ROCHELLE                          NY          0
# 1                        ADDIS                          LA          0
# 73                 LOS ANGELES                          CA          1
#
#      injure_sum  accident_count
# 87           48               2
# 36            6               1
# 23            4               1
# 74            3               1
# 19            2               1
# 123           2               1
# 34            2               4
# 9             2               1
# 70            1               1
# 79            1               1
# 25            1               2
# 120           1               1
# 104           1               1
# 112           1               1
# 110           1               2
# 57            1               1
# 93            1               1
# 85            1               1
# 1             1               1
# 73            1               1

# %%
# Cities with most fatalities
df_injure_fatal.sort_values('fatal_sum', ascending=False).head(20)
# Out:
#             location_city_name location_state_abbreviation  fatal_sum  \
# 87                    NEW YORK                          NY          8
# 123                 SWIFTWATER                          PA          1
# 65                LAKE CHARLES                          LA          1
# 39                     DUNMORE                          PA          1
# 17                   BRADENTON                          FL          1
# 62                JACKSONVILLE                          AR          1
# 23                      CANTON                          IL          1
# 73                 LOS ANGELES                          CA          1
# 99              PAGOSA SPRINGS                          CO          0
# 100                    PALATKA                          FL          0
# 98                 OTTAWA LAKE                          MI          0
# 91             NORTH LAS VEGAS                          NV          0
# 101                PEPPER PIKE                          OH          0
# 96                      OSPREY                          FL          0
# 95                       OMAHA                          NE          0
# 94   Not Within a Municipality                          ID          0
# 93   Not Within a Municipality                          IA          0
# 102                    PHOENIX                          AZ          0
# 103                 PITTSBURGH                          PA          0
# 92   Not Within a Municipality                          DC          0
#
#      injure_sum  accident_count
# 87           48               2
# 123           2               1
# 65            0               1
# 39            0               1
# 17            1               1
# 62            0               1
# 23            4               1
# 73            1               1
# 99            0               1
# 100           0               1
# 98            0               1
# 91            0               1
# 101           0               1
# 96            0               1
# 95            0               1
# 94            0               1
# 93            1               1
# 102           0               1
# 103           0               1
# 92            0               1

# %% [markdown]
# ## Incidents with highest fatalities and injuries

# %%
# Specific incidents with most fatalities
df.sort_values('fatal', ascending=False).head(10)
# Out:
#      datafile_as_of   ff significant serious  report_number  \
# 450         2/28/22   NO         YES     YES       20140031
# 2110        2/28/22  NaN         YES     YES       20160054
# 53          2/28/22  YES          NO      NO       20100062
# 1830        2/28/22  NaN         YES     YES       20140071
# 1134        2/28/22   NO         YES     YES       20200057
# 1197        2/28/22   NO         YES     YES       20210001
# 1206        2/28/22   NO         YES     YES       20210013
# 1219        2/28/22   NO         YES     YES       20210028
# 526         2/28/22   NO         YES     YES       20150001
# 3648        2/28/22  NaN         YES     YES       20120198
#
#       supplemental_number report_received_date         report_type  \
# 450                 16185              4/11/14  SUPPLEMENTAL FINAL
# 2110                31659              6/30/16  SUPPLEMENTAL FINAL
# 53                  15530              8/17/10  SUPPLEMENTAL FINAL
# 1830                16460              6/30/14  SUPPLEMENTAL FINAL
# 1134                34645              6/18/20  SUPPLEMENTAL FINAL
# 1197                35863               1/2/21  SUPPLEMENTAL FINAL
# 1206                34759              1/24/21            ORIGINAL
# 1219                34968               3/8/21  SUPPLEMENTAL FINAL
# 526                 30418               1/2/15  SUPPLEMENTAL FINAL
# 3648                17443              6/29/12        SUPPLEMENTAL
#
#       operator_id                                      name  \
# 450          2704        CONSOLIDATED EDISON CO OF NEW YORK
# 2110        31594          SOUTHCROSS CCNG TRANSMISSION LTD
# 53          18484                SOUTHERN CALIFORNIA GAS CO
# 1830        31968              WTG GAS TRANSMISSION COMPANY
# 1134         4499  CENTERPOINT ENERGY RESOURCES CORPORATION
# 1197        15348                    PEOPLES GAS SYSTEM INC
# 1206        20010                        UGI UTILITIES, INC
# 1219          603        CENTERPOINT ENERGY RESOURCES CORP.
# 526         15259                      UGI PENN NATURAL GAS
# 3648        14194                    OILTANKING, HOUSTON LP
#
#             operator_street_address operator_city_name  \
# 450                 4 IRVING PLACE            NEW YORK
# 2110  2103 CITYWEST BLVD. SUITE 900            HOUSTON
# 53           555 WEST FIFTH STREET         LOS ANGELES
# 1830    303 VETERANS AIRPARK LANE              MIDLAND
# 1134             1111 LOUISIANA ST             HOUSTON
# 1197                   PO BOX 2562               TAMPA
# 1206                   1 UGI DRIVE              DENVER
# 1219  1400 CENTERVIEW DR  SUITE 100        LITTLE ROCK
# 526                    1 UGI DRIVE              DENVER
# 3648  9805 KATY FREEWAY, SUITE 400             HOUSTON
#
#      operator_state_abbreviation operator_postal_code local_datetime  \
# 450                           NY                10003   3/12/14 9:31
# 2110                          TX                77042  4/12/16 12:15
# 53                            CA                90013   7/30/10 6:49
# 1830                          TX                79705   6/1/14 19:45
# 1134                          TX                77002  5/28/20 14:03
# 1197                          FL                33601  12/3/20 17:11
# 1206                          PA                17517  12/25/20 1:30
# 1219                          AR                72211   2/6/21 17:28
# 526                           PA                17517   12/4/14 3:51
# 3648                          TX                77024    6/2/12 8:10
#
#      time_zone daylight_savings_ind  iyear  \
# 450        NaN                  NaN   2014
# 2110       NaN                  NaN   2016
# 53         NaN                  NaN   2010
# 1830       NaN                  NaN   2014
# 1134   CENTRAL                  YES   2020
# 1197   EASTERN                   NO   2020
# 1206   EASTERN                   NO   2020
# 1219   CENTRAL                   NO   2021
# 526        NaN                  NaN   2014
# 3648       NaN                  NaN   2012
#
#                      location_street_address location_city_name  \
# 450                    1644/1646 PARK AVENUE           NEW YORK
# 2110                                     NaN                NaN
# 53                         890 E 59TH STREET        LOS ANGELES
# 1830                                     NaN                NaN
# 1134                     401 WEST MCNEESE ST       LAKE CHARLES
# 1197  8TH STREET CT. WEST @ 30TH AVENUE WEST          BRADENTON
# 1206               117 LOWER SWIFTWATER ROAD         SWIFTWATER
# 1219                   1900 BLOCK OF HWY 161       JACKSONVILLE
# 526                         413 SMITH STREET            DUNMORE
# 3648                                     NaN                NaN
#
#      location_county_name location_state_abbreviation location_postal_code  \
# 450              NEW YORK                          NY           10035-4645
# 2110                  NaN                         NaN                  NaN
# 53            LOS ANGELES                          CA                90001
# 1830                  NaN                         NaN                  NaN
# 1134            CALCASIEU                          LA                70605
# 1197              MANATEE                          FL                34205
# 1206               MONROE                          PA                18370
# 1219              PULASKI                          AR                72076
# 526            LACKAWANNA                          PA                18512
# 3648                  NaN                         NaN                  NaN
#
#       location_latitude  location_longitude  total_cost  total_cost_current  \
# 450           40.799726          -73.943401     2960200        3.339637e+06
# 2110          28.173489          -97.283219        1845        1.705755e+03
# 53            33.986780         -118.259640        2000        2.434421e+03
# 1830          32.220428         -102.104747        7970        8.991874e+03
# 1134          30.175900          -93.224400       73854        7.532606e+04
# 1197          27.473781          -82.570472      128973        1.315322e+05
# 1206          41.095368          -75.326474       62165        6.336155e+04
# 1219          34.849640          -92.116340        8490        8.490000e+03
# 526           41.414137          -75.625221      530300        5.976067e+05
# 3648          29.747769          -95.129993           0        0.000000e+00
#
#      injury_ind  injure  num_pub_evacuated  fatal                       cause  \
# 450         YES      48              100.0      8        NATURAL FORCE DAMAGE
# 2110        YES       1                0.0      2           EQUIPMENT FAILURE
# 53          YES       1              100.0      1  OTHER OUTSIDE FORCE DAMAGE
# 1830         NO       0                0.0      1           EQUIPMENT FAILURE
# 1134         NO       0                0.0      1  OTHER OUTSIDE FORCE DAMAGE
# 1197        YES       1              205.0      1           EXCAVATION DAMAGE
# 1206        YES       2                2.0      1        OTHER INCIDENT CAUSE
# 1219         NO       0                0.0      1  OTHER OUTSIDE FORCE DAMAGE
# 526          NO       0               45.0      1  OTHER OUTSIDE FORCE DAMAGE
# 3648        YES       1                0.0      1        OTHER INCIDENT CAUSE
#
#                                           cause_details  \
# 450       EARTH MOVEMENT, NOT DUE TO HEAVY RAINS/FLOODS
# 2110                            OTHER EQUIPMENT FAILURE
# 53    NEARBY INDUSTRIAL, MAN-MADE, OR OTHER FIRE/EXP...
# 1830               THREADED CONNECTION/COUPLING FAILURE
# 1134  DAMAGE BY CAR, TRUCK, OR OTHER MOTORIZED VEHIC...
# 1197                   EXCAVATION DAMAGE BY THIRD PARTY
# 1206                                            UNKNOWN
# 1219  DAMAGE BY CAR, TRUCK, OR OTHER MOTORIZED VEHIC...
# 526                          OTHER OUTSIDE FORCE DAMAGE
# 3648                                            UNKNOWN
#
#                                               narrative  \
# 450   DESCRIPTION OF INCIDENT:    ON MARCH 12, 2014 ...
# 2110  THE INCIDENT OCCURRED DURING THE COMPLETION OF...
# 53    ON JULY 30, AT APPROXIMATELY 6:50 AM, AN EXPLO...
# 1830  WTG GAS TRANSMISSION COMPANY WAS IN THE PROCES...
# 1134  VEHICLE LEFT THE ROADWAY AND MADE IMPACT TO CE...
# 1197  DAMAGED 2" PE MAIN BY THIRD PARTY NEXT GENERAT...
# 1206  AT APPROXIMATELY 1:44 AM DECEMBER 25, 2020, UG...
# 1219  A VEHICLE HEADING NORTH ON HWY 161 LOST CONTRO...
# 526   ON DECEMBER 4, 2014, BETWEEN 1:00 AM AND 2:23 ...
# 3648  ON 6-2-2012 ( SATURDAY ) A CONTRACTOR WAS WELD...
#
#       unintentional_release installation_year
# 450                    30.0        2011-01-01
# 2110                  738.0        2016-01-01
# 53                      0.0        2010-01-01
# 1830                    0.0        2013-01-01
# 1134                   11.0        2012-01-01
# 1197                  224.0        2014-01-01
# 1206                  975.0        2019-01-01
# 1219                  876.0        2020-01-01
# 526                   395.0        2014-01-01
# 3648                    NaN        2012-01-01

# %%
# Specific incidents with most injuries
df.sort_values('injure', ascending=False).head(10)
# Out:
#      datafile_as_of   ff significant serious  report_number  \
# 450         2/28/22   NO         YES     YES       20140031
# 455         2/28/22   NO         YES     YES       20140039
# 734         2/28/22   NO         YES     YES       20160126
# 5851        2/28/22  NaN         YES     YES       20170302
# 888         2/28/22   NO         YES     YES       20180058
# 6352        2/28/22  NaN         YES     YES       20180382
# 1111        2/28/22   NO         YES     YES       20200030
# 1206        2/28/22   NO         YES     YES       20210013
# 662         2/28/22   NO         YES     YES       20160043
# 4173        2/28/22  NaN         YES     YES       20130355
#
#       supplemental_number report_received_date         report_type  \
# 450                 16185              4/11/14  SUPPLEMENTAL FINAL
# 455                 16146              5/15/14  SUPPLEMENTAL FINAL
# 734                 31221             12/16/16  SUPPLEMENTAL FINAL
# 5851                31126              9/22/17  SUPPLEMENTAL FINAL
# 888                 33073              5/23/18  SUPPLEMENTAL FINAL
# 6352                32252             12/10/18  SUPPLEMENTAL FINAL
# 1111                33445              2/26/20  SUPPLEMENTAL FINAL
# 1206                34759              1/24/21            ORIGINAL
# 662                 16789              4/29/16  SUPPLEMENTAL FINAL
# 4173                20065             10/31/13  SUPPLEMENTAL FINAL
#
#       operator_id                                      name  \
# 450          2704        CONSOLIDATED EDISON CO OF NEW YORK
# 455         12408                           DTE GAS COMPANY
# 734         32513                   AMEREN ILLINOIS COMPANY
# 5851        39706  SUNOCO PARTNERS MARKETING & TERMINALS LP
# 888         18484                SOUTHERN CALIFORNIA GAS CO
# 6352        31130                             DCP MIDSTREAM
# 1111         1800         KEYSPAN ENERGY DELIVERY - NY CITY
# 1206        20010                        UGI UTILITIES, INC
# 662         15952          PUBLIC SERVICE ELECTRIC & GAS CO
# 4173        30829             ENTERPRISE CRUDE PIPELINE LLC
#
#             operator_street_address operator_city_name  \
# 450                 4 IRVING PLACE            NEW YORK
# 455              ONE ENERGY PLAZA              DETROIT
# 734               10 EXECUTIVE DR.        COLLINSVILLE
# 5851              1300 MAIN STREET             HOUSTON
# 888          555 WEST FIFTH STREET         LOS ANGELES
# 6352  6900 E. LAYTON AVE. SUITE 900             DENVER
# 1111                 40 SYLVAN RD.             WALTHAM
# 1206                   1 UGI DRIVE              DENVER
# 662        80 PARK PLAZA M/C - T18              NEWARK
# 4173         1100 LOUISIANA STREET             HOUSTON
#
#      operator_state_abbreviation operator_postal_code  local_datetime  \
# 450                           NY                10003    3/12/14 9:31
# 455                           MI                48226   3/27/14 20:07
# 734                           IL                62234  11/16/16 17:44
# 5851                          TX                77002   8/12/16 20:40
# 888                           CA                90013   4/23/18 15:45
# 6352                          CO           80237-3658  11/10/18 14:18
# 1111                          MA                02451   1/28/20 10:00
# 1206                          PA                17517   12/25/20 1:30
# 662                           NJ           07102-4194    3/30/16 9:05
# 4173                          TX                77002   9/30/13 18:45
#
#      time_zone daylight_savings_ind  iyear          location_street_address  \
# 450        NaN                  NaN   2014            1644/1646 PARK AVENUE
# 455        NaN                  NaN   2014                   19717 FAIRPORT
# 734        NaN                  NaN   2016                 50 N. 1ST AVENUE
# 5851       NaN                  NaN   2016                              NaN
# 888        NaN                  NaN   2018              13210 HOLLOWAY ROAD
# 6352       NaN                  NaN   2018                              NaN
# 1111       NaN                  NaN   2020  BAY RIDGE PARKWAY & 19TH AVENUE
# 1206   EASTERN                   NO   2020        117 LOWER SWIFTWATER ROAD
# 662        NaN                  NaN   2016                   CHOSIN FEW WAY
# 4173       NaN                  NaN   2013                              NaN
#
#      location_city_name location_county_name location_state_abbreviation  \
# 450            NEW YORK             NEW YORK                          NY
# 455             DETROIT                WAYNE                          MI
# 734              CANTON               FULTON                          IL
# 5851                NaN                  NaN                         NaN
# 888          LOST HILLS                 KERN                          CA
# 6352                NaN                  NaN                         NaN
# 1111           BROOKLYN                KINGS                          NY
# 1206         SWIFTWATER               MONROE                          PA
# 662             BAYONNE               HUDSON                          NJ
# 4173                NaN                  NaN                         NaN
#
#      location_postal_code  location_latitude  location_longitude  total_cost  \
# 450            10035-4645          40.799726          -73.943401     2960200
# 455            48205-1723          42.440755          -82.991686       33348
# 734                 61520          40.556604          -90.033663     4383446
# 5851                  NaN          29.998010          -93.989940        3505
# 888                 93249          35.707755         -119.824190       60005
# 6352                  NaN          30.351556         -100.581792    15200000
# 1111                11204          40.612236          -73.993575       19696
# 1206                18370          41.095368          -75.326474       62165
# 662                 07002          40.674182          -74.102086           0
# 4173                  NaN          28.949448          -95.430748        5000
#
#       total_cost_current injury_ind  injure  num_pub_evacuated  fatal  \
# 450         3.339637e+06        YES      48              100.0      8
# 455         3.762371e+04        YES       6                0.0      0
# 734         4.841442e+06        YES       4               50.0      1
# 5851        3.871233e+03        YES       4                0.0      0
# 888         6.371394e+04        YES       3                0.0      0
# 6352        1.613984e+07        YES       2                0.0      0
# 1111        2.008691e+04        YES       2                0.0      0
# 1206        6.336155e+04        YES       2                2.0      1
# 662         0.000000e+00        YES       2                0.0      0
# 4173        5.750196e+03        YES       2                0.0      0
#
#                            cause  \
# 450         NATURAL FORCE DAMAGE
# 455   OTHER OUTSIDE FORCE DAMAGE
# 734            EXCAVATION DAMAGE
# 5851         INCORRECT OPERATION
# 888          INCORRECT OPERATION
# 6352           EXCAVATION DAMAGE
# 1111         INCORRECT OPERATION
# 1206        OTHER INCIDENT CAUSE
# 662          INCORRECT OPERATION
# 4173         INCORRECT OPERATION
#
#                                           cause_details  \
# 450       EARTH MOVEMENT, NOT DUE TO HEAVY RAINS/FLOODS
# 455                                  INTENTIONAL DAMAGE
# 734                    EXCAVATION DAMAGE BY THIRD PARTY
# 5851                   EQUIPMENT NOT INSTALLED PROPERLY
# 888                          OTHER INCORRECT OPERATION
# 6352                   EXCAVATION DAMAGE BY THIRD PARTY
# 1111  DAMAGE BY OPERATOR OR OPERATOR'S CONTRACTOR NO...
# 1206                                            UNKNOWN
# 662                          OTHER INCORRECT OPERATION
# 4173                         OTHER INCORRECT OPERATION
#
#                                               narrative  \
# 450   DESCRIPTION OF INCIDENT:    ON MARCH 12, 2014 ...
# 455   AT 20:07, ON THURSDAY, MARCH 27, 2014, DTE GAS...
# 734   FINAL UPDATE 11/21/2018 - THE TOTAL DAMAGES IN...
# 5851  A CONSTRUCTION PROJECT WAS UNDERWAY TO TIE IN ...
# 888   AT APPROXIMATELY 3:50 PM, ON MONDAY 04-23-2018...
# 6352  DCP CONTRACT LINE LOCATOR GUADALUPE VALDES PRO...
# 1111  GAS FIELD OPERATIONS SENIOR SUPERVISOR REPORTE...
# 1206  AT APPROXIMATELY 1:44 AM DECEMBER 25, 2020, UG...
# 662   ON MARCH 30, 2016, AT APPROXIMATELY 9:00 A.M. ...
# 4173  AT THE TIME OF THE ACCIDENT, THE PIPELINE WAS ...
#
#       unintentional_release installation_year
# 450                   30.00        2011-01-01
# 455                    0.00        2011-01-01
# 734                   33.29        2012-01-01
# 5851                    NaN        2016-01-01
# 888                    0.87        2018-01-01
# 6352                    NaN        2013-01-01
# 1111                  21.50        2017-01-01
# 1206                 975.00        2019-01-01
# 662                    0.00        2015-01-01
# 4173                    NaN        2013-01-01
